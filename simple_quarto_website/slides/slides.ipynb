# %% [raw]
# ---
# title: "My Dog"
# author: "Isak Dai"
# format:
#     revealjs:
#         code-fold: true
# bibliography: ../reference.bib
# jupyter: python3
# execute:
#   enabled: true
# ---

# %% [markdown]
# ## Bounty
#
# ![image](../images/IMG_5564.jpg){width=40%}
#
# - He is 14 [@curiel2024power]
#
# ## Havanese
#
# ![image](../images/IMG_9443.jpg){width=40%}
#
# - Bounty is a Havanese. Many Havanese are show dogs, but Bounty will only sit or shake for treats.
#
# ##
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# ypoints = np.array([3, 8, 1, 10])
#
# plt.plot(ypoints, linestyle = 'dotted')
# plt.show()
# ```
#
#
# ##

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()
